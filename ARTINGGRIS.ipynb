# %%
import nltk #import library nltk
from nltk.tokenize import word_tokenize #import word_tokenize for tokenizing text into words 
from nltk.tokenize import sent_tokenize #import sent_tokenize for tokenizing paragraph into sentences
from nltk.stem.porter import PorterStemmer #import Porter Stemmer Algorithm 
from nltk.stem import WordNetLemmatizer #import WordNet lemmatizer 
from nltk.corpus import stopwords #import stopwords
from nltk.tokenize import RegexpTokenizer
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory #import Indonesian Stemmer
import re #import regular expression

# %%
#casefolding
def casefolding(s):
    new_str = s.lower()
    
    return new_str


#remove digit from string
def removeDigit(str):
    new_string =  re.sub(r"[\W]", " ", str)
    return new_string

stop_words = set(stopwords.words('english')) 

def stpwrd(str):  
    word_tokens = word_tokenize(str) 
    filtered_sentence = [w for w in word_tokens if not w in stop_words] 
    filtered_sentence = [] 
    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w) 
    return filtered_sentence

def stmr(str):
    porter_stemmer = PorterStemmer()
    # First Word tokenization
    nltk_tokens = nltk.word_tokenize(str)
    #Next find the roots of the word
    for w in nltk_tokens:
        print("Actual: %s  Stem: %s"  % (w,porter_stemmer.stem(w)))

# %%
file = open('MERCEDES.txt', 'r')
text_data = file.read()
stop=casefolding(text_data)
stop=removeDigit(stop)
stop=stpwrd(stop)
listOK1 = list(set(stop))
str2 = ' '.join(listOK1)
FIX2 = ' '.join( [w for w in str2.split() if len(w)>1])
print(stmr(FIX2))
# Out:
# Actual: usa  Stem: usa
# Actual: around  Stem: around
# Actual: suvs  Stem: suv
# Actual: yet  Stem: yet
# Actual: gls  Stem: gl
# Actual: assembled  Stem: assembl
# Actual: facilities  Stem: facil
# Actual: joining  Stem: join
# Actual: city  Stem: citi
# Actual: best  Stem: best
# Actual: 2019  Stem: 2019
# Actual: world  Stem: world
# Actual: year  Stem: year
# Actual: coincide  Stem: coincid
# Actual: model  Stem: model
# Actual: compact  Stem: compact
# Actual: versions  Stem: version
# Actual: marking  Stem: mark
# Actual: earlier  Stem: earlier
# Actual: gle  Stem: gle
# Actual: vehicle  Stem: vehicl
# Actual: alabama  Stem: alabama
# Actual: selling  Stem: sell
# Actual: may  Stem: may
# Actual: manufactured  Stem: manufactur
# Actual: importing  Stem: import
# Actual: ford  Stem: ford
# Actual: confirmed  Stem: confirm
# Actual: automotive  Stem: automot
# Actual: states  Stem: state
# Actual: built  Stem: built
# Actual: offered  Stem: offer
# Actual: went  Stem: went
# Actual: larger  Stem: larger
# Actual: class  Stem: class
# Actual: first  Stem: first
# Actual: introduced  Stem: introduc
# Actual: 2020  Stem: 2020
# Actual: mercedes  Stem: merced
# Actual: indian  Stem: indian
# Actual: ecosport  Stem: ecosport
# Actual: benz  Stem: benz
# Actual: updated  Stem: updat
# Actual: currently  Stem: current
# Actual: german  Stem: german
# Actual: alongside  Stem: alongsid
# Actual: start  Stem: start
# Actual: imported  Stem: import
# Actual: second  Stem: second
# Actual: made  Stem: made
# Actual: united  Stem: unit
# Actual: germany  Stem: germani
# Actual: spokesman  Stem: spokesman
# Actual: including  Stem: includ
# Actual: glcs  Stem: glc
# Actual: market  Stem: market
# Actual: suv  Stem: suv
# Actual: one  Stem: one
# Actual: body  Stem: bodi
# Actual: glc  Stem: glc
# Actual: sold  Stem: sold
# Actual: begin  Stem: begin
# Actual: october  Stem: octob
# Actual: different  Stem: differ
# Actual: several  Stem: sever
# Actual: news  Stem: news
# Actual: styles  Stem: style
# Actual: subcompact  Stem: subcompact
# Actual: automaker  Stem: automak
# Actual: sale  Stem: sale
# Actual: india  Stem: india
# Actual: drivetrains  Stem: drivetrain
# Actual: starting  Stem: start
# Actual: reveal  Stem: reveal
# Actual: clarified  Stem: clarifi
# Actual: expected  Stem: expect
# Actual: company  Stem: compani
# Actual: car  Stem: car
# Actual: pune  Stem: pune
# Actual: move  Stem: move
# None
